# %% [markdown]
# <a href="https://colab.research.google.com/github/brianisinga/stock-price-predictions/blob/main/tesla_stock_price_predictions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline
import chart_studio.plotly as py
import plotly.graph_objs as go
#for offline ploting
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
init_notebook_mode(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.24.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
#estavlishing connection btwn G-drive and colab
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
tesla = pd.read_csv('/content/drive/MyDrive/machine learning projects/tesla stock predictions/tesla.csv')

# %%
tesla.head()
# Out:
#          Date       Open   High        Low      Close  Adj Close    Volume
# 0  29-06-2010  19.000000  25.00  17.540001  23.889999  23.889999  18766300
# 1  30-06-2010  25.790001  30.42  23.299999  23.830000  23.830000  17187100
# 2  01-07-2010  25.000000  25.92  20.270000  21.959999  21.959999   8218800
# 3  02-07-2010  23.000000  23.10  18.709999  19.200001  19.200001   5139800
# 4  06-07-2010  20.000000  20.00  15.830000  16.110001  16.110001   6866900

# %%
tesla.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2193 entries, 0 to 2192
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       2193 non-null   object
#  1   Open       2193 non-null   float64
#  2   High       2193 non-null   float64
#  3   Low        2193 non-null   float64
#  4   Close      2193 non-null   float64
#  5   Adj Close  2193 non-null   float64
#  6   Volume     2193 non-null   int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 120.1+ KB

# %%
#This line of code converts the 'Date' column in the tesla dataframe to datetime objects. This is useful for time series analysis and plotting.
tesla['Date'] = pd.to_datetime(tesla['Date'])
# Out:
# <ipython-input-17-a76b2f650505>:2: UserWarning:
#
# Parsing dates in %d-%m-%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.

# %%
print(f'The first date in the dataset is {tesla["Date"].min()}')
print(f'The last date in the dataset is {tesla["Date"].max()})')
# Out:
# The first date in the dataset is 2010-06-29 00:00:00
# The last date in the dataset is 2019-03-15 00:00:00)

# %%
print(f'the total number of days = {(tesla.Date.max() - tesla.Date.min())}')
# Out:
# the total number of days = 3181 days 00:00:00

# %%
tesla.describe()
# Out:
#                                 Date         Open         High          Low  \
# count                           2193  2193.000000  2193.000000  2193.000000
# mean   2014-11-04 14:37:15.841313024   175.652882   178.710262   172.412075
# min              2010-06-29 00:00:00    16.139999    16.629999    14.980000
# 25%              2012-08-29 00:00:00    33.110001    33.910000    32.459999
# 50%              2014-11-04 00:00:00   204.990005   208.160004   201.669998
# 75%              2017-01-09 00:00:00   262.000000   265.329987   256.209991
# max              2019-03-15 00:00:00   386.690002   389.609985   379.350006
# std                              NaN   115.580903   117.370092   113.654794
#
#              Close    Adj Close        Volume
# count  2193.000000  2193.000000  2.193000e+03
# mean    175.648555   175.648555  5.077449e+06
# min      15.800000    15.800000  1.185000e+05
# 25%      33.160000    33.160000  1.577800e+06
# 50%     204.990005   204.990005  4.171700e+06
# ...

# %%
#setting a layout fot the plot
